# %%
import Plant_Tracker

# %%
Plant_Tracker.main()
# Out:
# Welcome to Plant Care Tracker!
#
# === Plant Care Tracker ===
# 1. Add a new plant
# 2. Record care activity
# 3. View plants due for care
# 4. Search plants
# 5. View all plants
# 6. Exit
# Enter your choice:  1
# New plants.csv created.
#
# === Add a New Plant ===
# Enter plant name:  cycus
# Enter plant location:  front porch
# Enter date acquired (YYYY-MM-DD) or press Enter for today:
# Enter watering frequency (days):  1
# Sunlight (Low/Medium/High):  medium
# Plant 'cycus' added successfully!
#
# === Plant Care Tracker ===
# 1. Add a new plant
# 2. Record care activity
# 3. View plants due for care
# 4. Search plants
# 5. View all plants
# 6. Exit
# Enter your choice:  5
# === All Plants ===
# {'id': 'b83db405', 'name': 'cycus', 'location': 'front porch', 'date_acquired': '2026-04-07', 'watering_frequency': '1', 'sunlight': 'medium', 'last_watered': ''}
#
# === Plant Care Tracker ===
# 1. Add a new plant
# 2. Record care activity
# 3. View plants due for care
# ...
