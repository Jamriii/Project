# %%
import Plant_Tracker

# %%
## Plant_Tracker.main()
# Out:
# Welcome to Plant Care Tracker!
#
# === Plant Care Tracker ===
# 1. Add a new plant
# 2. Record care activity
# 3. View plants due for care
# 4. Search plants
# 5. View all plants
# 6. Record plant growth
# 7. Add plant photo
# 8. Exit
# Enter your choice:  5
# === All Plants ===
#
# ID: eadb4c5f
# Name: Cycus
# Location: Front porch
# Watering Frequency: 3 days
# Sunlight: medium
# Last Watered:
# Latest Height: 120.0 cm
# Latest Photo: /Users/jamriii/Desktop/Personal/Courses/Data science/Class work/Python-Project/Project-01/Project-01/cycus
# ---------------------------
#
#
# ID: 61a48bf1
# Name: jasmin
# Location: backyard
# Watering Frequency: 2 days
# Sunlight: low
# Last Watered:
# Latest Height: 85.0 cm
# Latest Photo:
# ---------------------------
#
#
# === Plant Care Tracker ===
# 1. Add a new plant
# 2. Record care activity
# 3. View plants due for care
# 4. Search plants
# 5. View all plants
# 6. Record plant growth
# 7. Add plant photo
# 8. Exit
# Enter your choice:  2
# ...
